# %% [markdown]
# # Simple Pendulum Data Simulation
#
# This function generates simulated data for a **simple pendulum**. The period of a pendulum with length `L` and gravitational acceleration `g` is calculated as:
#
# `T = 2 * pi * sqrt(L / g)`
#
# We also add random noise to simulate more realistic measurements.

# %%
import numpy as np
import pandas as pd

# %%
def generate_pendulum_data(num_samples=1000, display_rows=10):
    L = np.random.uniform(0.5, 10.0, num_samples)
    g = np.random.uniform(2, 25, num_samples)
    T = 2 * np.pi * np.sqrt(L / g)
    noise = np.random.normal(0, 0.01, num_samples)
    T_noisy = T + noise
    df = pd.DataFrame({
        'length': L,
        'gravity': g,
        'period': T_noisy
    })
    display_df = df.head(display_rows).style.background_gradient(cmap='viridis').format({
        'length': "{:.2f} m",
        'gravity': "{:.2f} m/s²",
        'period': "{:.3f} s"
    })
    
    return df, display_df

# %%
pendulum_df, styled_df = generate_pendulum_data(num_samples=2000)
pendulum_df.to_csv('pendulum_data.csv', index=False)
print("✅ Data generated and saved to pendulum_data.csv")
styled_df
# Out:
# ✅ Data generated and saved to pendulum_data.csv
# <style type="text/css">
# #T_c3edc_row0_col0 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_c3edc_row0_col1 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_c3edc_row0_col2 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_c3edc_row1_col0 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_c3edc_row1_col1, #T_c3edc_row9_col1 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_c3edc_row1_col2 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_c3edc_row2_col0, #T_c3edc_row2_col2, #T_c3edc_row7_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c3edc_row2_col1, #T_c3edc_row7_col0, #T_c3edc_row7_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_c3edc_row3_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_c3edc_row3_col1 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_c3edc_row3_col2 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_c3edc_row4_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_c3edc_row4_col1 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_c3edc_row4_col2 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_c3edc_row5_col0 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_c3edc_row5_col1 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_c3edc_row5_col2 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_c3edc_row6_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_c3edc_row6_col1 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_c3edc_row6_col2 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_c3edc_row8_col0 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_c3edc_row8_col1 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_c3edc_row8_col2 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_c3edc_row9_col0 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_c3edc_row9_col2 {
#   background-color: #5ec962;
#   color: #000000;
# }
# </style>
# <table id="T_c3edc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3edc_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_c3edc_level0_col1" class="col_heading level0 col1" >gravity</th>
#       <th id="T_c3edc_level0_col2" class="col_heading level0 col2" >period</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3edc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3edc_row0_col0" class="data row0 col0" >7.60 m</td>
#       <td id="T_c3edc_row0_col1" class="data row0 col1" >13.04 m/s²</td>
#       <td id="T_c3edc_row0_col2" class="data row0 col2" >4.795 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3edc_row1_col0" class="data row1 col0" >6.28 m</td>
#       <td id="T_c3edc_row1_col1" class="data row1 col1" >9.99 m/s²</td>
#       <td id="T_c3edc_row1_col2" class="data row1 col2" >4.961 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3edc_row2_col0" class="data row2 col0" >8.62 m</td>
#       <td id="T_c3edc_row2_col1" class="data row2 col1" >6.75 m/s²</td>
#       <td id="T_c3edc_row2_col2" class="data row2 col2" >7.092 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3edc_row3_col0" class="data row3 col0" >5.29 m</td>
#       <td id="T_c3edc_row3_col1" class="data row3 col1" >9.31 m/s²</td>
#       <td id="T_c3edc_row3_col2" class="data row3 col2" >4.743 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3edc_row4_col0" class="data row4 col0" >1.57 m</td>
#       <td id="T_c3edc_row4_col1" class="data row4 col1" >8.74 m/s²</td>
#       <td id="T_c3edc_row4_col2" class="data row4 col2" >2.673 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3edc_row5_col0" class="data row5 col0" >4.96 m</td>
#       <td id="T_c3edc_row5_col1" class="data row5 col1" >17.09 m/s²</td>
#       <td id="T_c3edc_row5_col2" class="data row5 col2" >3.372 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3edc_row6_col0" class="data row6 col0" >4.98 m</td>
#       <td id="T_c3edc_row6_col1" class="data row6 col1" >15.65 m/s²</td>
#       <td id="T_c3edc_row6_col2" class="data row6 col2" >3.552 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3edc_row7_col0" class="data row7 col0" >1.54 m</td>
#       <td id="T_c3edc_row7_col1" class="data row7 col1" >24.92 m/s²</td>
#       <td id="T_c3edc_row7_col2" class="data row7 col2" >1.558 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3edc_row8_col0" class="data row8 col0" >3.24 m</td>
#       <td id="T_c3edc_row8_col1" class="data row8 col1" >21.91 m/s²</td>
#       <td id="T_c3edc_row8_col2" class="data row8 col2" >2.408 s</td>
#     </tr>
#     <tr>
#       <th id="T_c3edc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3edc_row9_col0" class="data row9 col0" >8.22 m</td>
#       <td id="T_c3edc_row9_col1" class="data row9 col1" >9.95 m/s²</td>
#       <td id="T_c3edc_row9_col2" class="data row9 col2" >5.722 s</td>
#     </tr>
#   </tbody>
# </table>
